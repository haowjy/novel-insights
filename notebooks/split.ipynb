# %%
import sys
import os
sys.path.insert(1, os.path.join(os.getcwd()  , '..'))

# %%
from fff import epubsplit

# %%
file1='../data/frankenstein.epub'

# %%
esplit = epubsplit.SplitEpub(file1)

# %%
esplit.get_toc_map()
# Out:
# {'OEBPS/1228567360564846044_84-h-0.htm.xhtml': [('Frankenstein;',
#    'pgepubid00000'),
#   ('or, the Modern Prometheus', 'pgepubid00001')],
#  'OEBPS/1228567360564846044_84-h-1.htm.xhtml': [('CONTENTS', 'pgepubid00002')],
#  'OEBPS/1228567360564846044_84-h-2.htm.xhtml': [('Letter 1', 'pgepubid00003')],
#  'OEBPS/1228567360564846044_84-h-3.htm.xhtml': [('Letter 2', 'pgepubid00004')],
#  'OEBPS/1228567360564846044_84-h-4.htm.xhtml': [('Letter 3', 'pgepubid00005')],
#  'OEBPS/1228567360564846044_84-h-5.htm.xhtml': [('Letter 4', 'pgepubid00006')],
#  'OEBPS/1228567360564846044_84-h-6.htm.xhtml': [('Chapter 1',
#    'pgepubid00007')],
#  'OEBPS/1228567360564846044_84-h-7.htm.xhtml': [('Chapter 2',
#    'pgepubid00008')],
#  'OEBPS/1228567360564846044_84-h-8.htm.xhtml': [('Chapter 3',
#    'pgepubid00009')],
#  'OEBPS/1228567360564846044_84-h-9.htm.xhtml': [('Chapter 4',
#    'pgepubid00010')],
#  'OEBPS/1228567360564846044_84-h-10.htm.xhtml': [('Chapter 5',
#    'pgepubid00011')],
# ...

# %%
esplit.get_split_lines()
# Out:
# /home/jimmy/repos/novel-insights/notebooks/../fff/epubsplit.py:1180: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(data,'html5lib')
# [{'href': 'OEBPS/wrap0000.xhtml',
#   'anchor': None,
#   'toc': [],
#   'id': 'coverpage-wrapper',
#   'type': 'application/xhtml+xml',
#   'num': 0,
# ...
